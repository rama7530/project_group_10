# %%
# !pip install openpyxl
# !pip install Flask
import sqlite3
import pandas as pd
# Out:
# C:\Users\ramak\AppData\Local\Temp\ipykernel_21716\2353985848.py:4: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_excel("IMDB Top250 Movies.xlsx")

# %%
df.head()
# Out:
#                Movies Names Rating out of 10 Count of Ratings  \
# 0  The Shawshank Redemption              9.3             2.9M
# 1             The Godfather              9.2               2M
# 2           The Dark Knight              9.0             2.9M
# 3    The Godfather: Part II              9.0             1.4M
# 4              12 Angry Men              9.0             861K
#
#                      Release Date                    Budget Domestic Gross  \
# 0        October 14, 1994 (India)   $25,000,000 (estimated)    US & Canada
# 1                    1978 (India)    $6,000,000 (estimated)    US & Canada
# 2           July 18, 2008 (India)  $185,000,000 (estimated)    US & Canada
# 3                    1979 (India)   $13,000,000 (estimated)    US & Canada
# 4  April 10, 1957 (United States)      $350,000 (estimated)    US & Canada
#
#   Domestic Gross2 Domestic Weekend Gross Domestic Weekend  \
# 0       $28767189            US & Canada          $727327
# 1      $136381073            US & Canada          $302393
# 2      $534987076            US & Canada       $158411483
# 3       $47834595            US & Canada          $171417
# 4       Not Found            US & Canada        Not Found
#
#   Domestic Weekend Gross Date Worldwide Gross
# 0                 Sep 25 1994     $28,904,642
# 1                 Mar 19 1972    $250,342,030
# 2                 Jul 20 2008  $1,008,486,720
# 3                 Nov 10 2019     $47,962,897
# 4                   Not Found          $2,667

# %%
con = sqlite3.connect("IMDB.db")
cursor = con.cursor()

# %%
df.to_sql("Movies", con, if_exists='replace', index=False)
# Out:
# 250

# %%
cursor.execute("Select * from Movies").fetchall()
# Out:
# [('The Shawshank Redemption',
#   '9.3',
#   '2.9M',
#   'October 14, 1994 (India)',
#   '$25,000,000 (estimated)',
#   'US & Canada',
#   '$28767189',
#   'US & Canada',
#   '$727327',
#   'Sep 25 1994',
#   '$28,904,642'),
#  ('The Godfather',
#   '9.2',
#   '2M',
#   '1978 (India)',
#   '$6,000,000 (estimated)',
#   'US & Canada',
#   '$136381073',
#   'US & Canada',
#   '$302393',
#   'Mar 19 1972',
#   '$250,342,030'),
#  ('The Dark Knight',
#   '9.0',
#   '2.9M',
#   'July 18, 2008 (India)',
#   '$185,000,000 (estimated)',
#   'US & Canada',
#   '$534987076',
#   'US & Canada',
#   '$158411483',
#   'Jul 20 2008',
#   '$1,008,486,720'),
#  ('The Godfather: Part II',
#   '9.0',
#   '1.4M',
#   '1979 (India)',
#   '$13,000,000 (estimated)',
#   'US & Canada',
#   '$47834595',
#   'US & Canada',
#   '$171417',
#   'Nov 10 2019',
#   '$47,962,897'),
#  ('12 Angry Men',
#   '9.0',
#   '861K',
#   'April 10, 1957 (United States)',
#   '$350,000 (estimated)',
#   'US & Canada',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$2,667'),
#  ("Schindler's List",
#   '9.0',
#   '1.4M',
#   'December 15, 1993 (India)',
#   '$22,000,000 (estimated)',
#   'US & Canada',
#   '$96898818',
#   'US & Canada',
#   '$656636',
#   'Dec 19 1993',
#   '$322,161,245'),
#  ('The Lord of the Rings: The Return of the King',
#   '9.0',
#   '2M',
#   'February 6, 2004 (India)',
#   '$94,000,000 (estimated)',
#   'US & Canada',
#   '$379427292',
#   'US & Canada',
#   '$72629713',
#   'Dec 21 2003',
#   '$1,156,598,523'),
#  ('Pulp Fiction',
#   '8.9',
#   '2.2M',
#   'October 14, 1994 (India)',
#   '$8,000,000 (estimated)',
#   'US & Canada',
#   '$107928762',
#   'US & Canada',
#   '$9311882',
#   'Oct 16 1994',
#   '$213,928,762'),
#  ('The Lord of the Rings: The Fellowship of the Ring',
#   '8.9',
#   '2M',
#   'March 15, 2002 (India)',
#   '$93,000,000 (estimated)',
#   'US & Canada',
#   '$316115420',
#   'US & Canada',
#   '$47211490',
#   'Dec 23 2001',
#   '$884,041,698'),
#  ('Il Buono, Il Brutto, Il Cattivo',
#   '8.8',
#   '809K',
#   'April 15, 1969 (India)',
#   '$1,200,000 (estimated)',
#   'US & Canada',
#   '$25100000',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$25,259,657'),
#  ('Forrest Gump',
#   '8.8',
#   '2.2M',
#   'September 12, 2014 (India)',
#   '$55,000,000 (estimated)',
#   'US & Canada',
#   '$330455270',
#   'US & Canada',
#   '$24450602',
#   'Jul 10 1994',
#   '$678,226,465'),
#  ('The Lord of the Rings: The Two Towers',
#   '8.8',
#   '1.8M',
#   'March 28, 2003 (India)',
#   '$94,000,000 (estimated)',
#   'US & Canada',
#   '$342952511',
#   'US & Canada',
#   '$62007528',
#   'Dec 22 2002',
#   '$948,945,489'),
#  ('Fight Club',
#   '8.8',
#   '2.3M',
#   'October 15, 1999 (India)',
#   '$63,000,000 (estimated)',
#   'US & Canada',
#   '$37030102',
#   'US & Canada',
#   '$11035485',
#   'Oct 17 1999',
#   '$101,320,107'),
#  ('Inception',
#   '8.8',
#   '2.5M',
#   'July 16, 2010 (India)',
#   '$160,000,000 (estimated)',
#   'US & Canada',
#   '$292587330',
#   'US & Canada',
#   '$62785337',
#   'Jul 18 2010',
#   '$839,030,630'),
#  ('Dune: Part Two',
#   '8.8',
#   '290K',
#   'March 1, 2024 (India)',
#   '$190,000,000 (estimated)',
#   'US & Canada',
#   '$244890027',
#   'US & Canada',
#   '$82505391',
#   'Mar 3 2024',
#   '$587,090,027'),
#  ('Star Wars: Episode V - The Empire Strikes Back',
#   '8.7',
#   '1.4M',
#   'December 10, 1980 (India)',
#   '$18,000,000 (estimated)',
#   'US & Canada',
#   '$292753960',
#   'US & Canada',
#   '$4910483',
#   'May 25 1980',
#   '$538,375,067'),
#  ('The Matrix',
#   '8.7',
#   '2M',
#   'May 31, 2020 (India)',
#   '$63,000,000 (estimated)',
#   'US & Canada',
#   '$172076928',
#   'US & Canada',
#   '$27788331',
#   'Apr 4 1999',
#   '$467,623,299'),
#  ('GoodFellas',
#   '8.7',
#   '1.3M',
#   'July 31, 2019 (India)',
#   '$25,000,000 (estimated)',
#   'US & Canada',
#   '$46909721',
#   'US & Canada',
#   '$6368901',
#   'Sep 23 1990',
#   '$47,049,784'),
#  ("One Flew Over the Cuckoo's Nest",
#   '8.7',
#   '1.1M',
#   'March 10, 1977 (India)',
#   '$3,000,000 (estimated)',
#   'US & Canada',
#   '$108981275',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$109,114,987'),
#  ('Se7en',
#   '8.6',
#   '1.8M',
#   'September 22, 1995 (India)',
#   '$33,000,000 (estimated)',
#   'US & Canada',
#   '$100125643',
#   'US & Canada',
#   '$13949807',
#   'Sep 24 1995',
#   '$327,333,559'),
#  ('Interstellar',
#   '8.7',
#   '2.1M',
#   'November 7, 2014 (India)',
#   '$165,000,000 (estimated)',
#   'US & Canada',
#   '$188020017',
#   'US & Canada',
#   '$47510360',
#   'Nov 9 2014',
#   '$733,202,212'),
#  ("It's a Wonderful Life",
#   '8.6',
#   '498K',
#   'January 7, 1947 (United States)',
#   '$3,180,000 (estimated)',
#   'US & Canada',
#   '$1483643',
#   'US & Canada',
#   '$44000',
#   'Dec 20 2020',
#   '$9,767,242'),
#  ('Shichinin No Samurai',
#   '8.6',
#   '366K',
#   'April 26, 1954 (Japan)',
#   '¥125,000,000 (estimated)',
#   'US & Canada',
#   '$318649',
#   'US & Canada',
#   '$15942',
#   'Jul 28 2002',
#   '$346,258'),
#  ('The Silence of the Lambs',
#   '8.6',
#   '1.5M',
#   'February 14, 1991 (United States)',
#   '$19,000,000 (estimated)',
#   'US & Canada',
#   '$130742922',
#   'US & Canada',
#   '$13766814',
#   'Feb 18 1991',
#   '$272,742,922'),
#  ('Saving Private Ryan',
#   '8.6',
#   '1.5M',
#   'March 26, 1999 (India)',
#   '$70,000,000 (estimated)',
#   'US & Canada',
#   '$217049603',
#   'US & Canada',
#   '$30576104',
#   'Jul 26 1998',
#   '$482,351,251'),
#  ('City of God',
#   '8.6',
#   '798K',
#   'January 18, 2007 (India)',
#   'R$3,300,000 (estimated)',
#   'US & Canada',
#   '$7564459',
#   'US & Canada',
#   '$88292',
#   'Jan 19 2003',
#   '$30,680,793'),
#  ('Life Is Beautiful',
#   '8.6',
#   '741K',
#   'September 18, 2000 (India)',
#   '$20,000,000 (estimated)',
#   'US & Canada',
#   '$57563264',
#   'US & Canada',
#   '$118920',
#   'Oct 25 1998',
#   '$230,099,013'),
#  ('The Green Mile',
#   '8.6',
#   '1.4M',
#   'March 16, 2000 (India)',
#   '$60,000,000 (estimated)',
#   'US & Canada',
#   '$136801374',
#   'US & Canada',
#   '$18017152',
#   'Dec 12 1999',
#   '$286,801,374'),
#  ('Terminator 2: Judgment Day',
#   '8.6',
#   '1.2M',
#   'August 24, 1991 (India)',
#   '$102,000,000 (estimated)',
#   'US & Canada',
#   '$205881154',
#   'US & Canada',
#   '$31765506',
#   'Jul 7 1991',
#   '$520,881,154'),
#  ('Star Wars: Episode IV - A New Hope',
#   '8.6',
#   '1.4M',
#   'July 1, 1978 (India)',
#   '$11,000,000 (estimated)',
#   'US & Canada',
#   '$460998507',
#   'US & Canada',
#   '$1554475',
#   'May 30 1977',
#   '$775,398,007'),
#  ('Back to the Future',
#   '8.5',
#   '1.3M',
#   'December 9, 1986 (India)',
#   '$19,000,000 (estimated)',
#   'US & Canada',
#   '$214077472',
#   'US & Canada',
#   '$11152500',
#   'Jul 7 1985',
#   '$384,577,472'),
#  ('Spirited Away',
#   '8.6',
#   '845K',
#   'March 1, 2020 (India)',
#   '$19,000,000 (estimated)',
#   'US & Canada',
#   '$15205725',
#   'US & Canada',
#   '$449839',
#   'Sep 22 2002',
#   '$357,561,772'),
#  ('The Pianist',
#   '8.5',
#   '908K',
#   'April 3, 2019 (India)',
#   '$35,000,000 (estimated)',
#   'US & Canada',
#   '$32585488',
#   'US & Canada',
#   '$111261',
#   'Dec 29 2002',
#   '$120,093,683'),
#  ('Parasite',
#   '8.5',
#   '951K',
#   'January 31, 2020 (India)',
#   '$11,400,000 (estimated)',
#   'US & Canada',
#   '$53369749',
#   'US & Canada',
#   '$393216',
#   'Oct 13 2019',
#   '$262,099,264'),
#  ('Psycho',
#   '8.5',
#   '716K',
#   'May 24, 2020 (India)',
#   '$806,947 (estimated)',
#   'US & Canada',
#   '$32000000',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$32,060,008'),
#  ('Spider-man: Across the Spider-verse',
#   '8.6',
#   '362K',
#   'June 1, 2023 (India)',
#   '$150,000,000 (estimated)',
#   'US & Canada',
#   '$381593754',
#   'US & Canada',
#   '$120663589',
#   'Jun 4 2023',
#   '$690,897,910'),
#  ('Gladiator',
#   '8.5',
#   '1.6M',
#   'September 1, 2000 (India)',
#   '$103,000,000 (estimated)',
#   'US & Canada',
#   '$187705427',
#   'US & Canada',
#   '$34819017',
#   'May 7 2000',
#   '$465,387,186'),
#  ('The Lion King',
#   '8.5',
#   '1.1M',
#   'October 29, 1994 (India)',
#   '$45,000,000 (estimated)',
#   'US & Canada',
#   '$422783777',
#   'US & Canada',
#   '$1586753',
#   'Jun 19 1994',
#   '$968,750,694'),
#  ('Léon',
#   '8.5',
#   '1.2M',
#   'September 23, 1996 (India)',
#   'FRF\xa0115,000,000 (estimated)',
#   'US & Canada',
#   '$19501238',
#   'US & Canada',
#   '$5306558',
#   'Nov 20 1994',
#   '$19,570,198'),
#  ('The Departed',
#   '8.5',
#   '1.4M',
#   'October 31, 2007 (India)',
#   '$90,000,000 (estimated)',
#   'US & Canada',
#   '$132399394',
#   'US & Canada',
#   '$26887467',
#   'Oct 8 2006',
#   '$291,481,358'),
#  ('American History X',
#   '8.5',
#   '1.2M',
#   'September 21, 1999 (India)',
#   '$20,000,000 (estimated)',
#   'US & Canada',
#   '$6719864',
#   'US & Canada',
#   '$156076',
#   'Nov 1 1998',
#   '$23,875,714'),
#  ('Whiplash',
#   '8.5',
#   '983K',
#   'February 20, 2015 (India)',
#   '$3,300,000 (estimated)',
#   'US & Canada',
#   '$13092000',
#   'US & Canada',
#   '$135388',
#   'Oct 12 2014',
#   '$49,449,489'),
#  ('The Prestige',
#   '8.5',
#   '1.4M',
#   'October 20, 2006 (India)',
#   '$40,000,000 (estimated)',
#   'US & Canada',
#   '$53089891',
#   'US & Canada',
#   '$14801808',
#   'Oct 22 2006',
#   '$109,676,311'),
#  ('Grave of the Fireflies',
#   '8.5',
#   '309K',
#   'April 16, 1988 (Japan)',
#   '$3,700,000 (estimated)',
#   'US & Canada',
#   '$516962',
#   'US & Canada',
#   '$158101',
#   'Aug 12 2018',
#   '$519,421'),
#  ('Seppuku',
#   '8.6',
#   '68K',
#   'September 16, 1962 (Japan)',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$15,222'),
#  ('The Usual Suspects',
#   '8.5',
#   '1.1M',
#   'May 10, 1996 (India)',
#   '$6,000,000 (estimated)',
#   'US & Canada',
#   '$23341568',
#   'US & Canada',
#   '$645363',
#   'Aug 20 1995',
#   '$23,341,568'),
#  ('Casablanca',
#   '8.5',
#   '604K',
#   'January 23, 1943 (United States)',
#   '$950,000 (estimated)',
#   'US & Canada',
#   '$4219709',
#   'US & Canada',
#   '$181494',
#   'Apr 12 1992',
#   '$4,656,207'),
#  ('Intouchables',
#   '8.5',
#   '926K',
#   'July 13, 2012 (India)',
#   '€9,500,000 (estimated)',
#   'US & Canada',
#   '$10198820',
#   'US & Canada',
#   '$103507',
#   'May 27 2012',
#   '$426,590,315'),
#  ('Cinema Paradiso',
#   '8.5',
#   '282K',
#   'November 17, 1988 (Italy)',
#   '$5,000,000 (estimated)',
#   'US & Canada',
#   '$12397210',
#   'US & Canada',
#   '$16552',
#   'Feb 4 1990',
#   '$13,020,497'),
#  ('Not Found',
#   'Not Found',
#   None,
#   'Not Found',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   None),
#  ('Rear Window',
#   '8.5',
#   '521K',
#   'September 1, 1954 (United States)',
#   '$1,000,000 (estimated)',
#   'US & Canada',
#   '$36764313',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$37,039,396'),
#  ("C'era Una Volta Il West",
#   '8.5',
#   '348K',
#   'September 24, 1969 (India)',
#   '$5,000,000 (estimated)',
#   'US & Canada',
#   '$5321508',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$5,435,312'),
#  ('Alien',
#   '8.5',
#   '947K',
#   'December 6, 1979 (India)',
#   '$11,000,000 (estimated)',
#   'US & Canada',
#   '$81900459',
#   'US & Canada',
#   '$3527881',
#   'May 28 1979',
#   '$106,285,522'),
#  ('City Lights',
#   '8.5',
#   '195K',
#   'March 7, 1931 (United States)',
#   '$1,500,000 (estimated)',
#   'US & Canada',
#   '$19181',
#   'US & Canada',
#   '$9102',
#   'Jul 8 2007',
#   '$50,419'),
#  ('Apocalypse Now',
#   '8.4',
#   '708K',
#   'August 15, 1979 (United States)',
#   '$31,500,000 (estimated)',
#   'US & Canada',
#   '$96042913',
#   'US & Canada',
#   '$118558',
#   'Aug 19 1979',
#   '$104,911,478'),
#  ('Django Unchained',
#   '8.5',
#   '1.7M',
#   'March 22, 2013 (India)',
#   '$100,000,000 (estimated)',
#   'US & Canada',
#   '$162805434',
#   'US & Canada',
#   '$30122888',
#   'Dec 30 2012',
#   '$426,076,293'),
#  ('12th Fail',
#   '9.0',
#   '107K',
#   'October 27, 2023 (India)',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$138,288'),
#  ('Memento',
#   '8.4',
#   '1.3M',
#   'October 20, 2000 (India)',
#   '$9,000,000 (estimated)',
#   'US & Canada',
#   '$25544867',
#   'US & Canada',
#   '$235488',
#   'Mar 18 2001',
#   '$40,047,236'),
#  ('WALL·E',
#   '8.4',
#   '1.2M',
#   'August 29, 2008 (India)',
#   '$180,000,000 (estimated)',
#   'US & Canada',
#   '$223808164',
#   'US & Canada',
#   '$63087526',
#   'Jun 29 2008',
#   '$521,320,168'),
#  ('Raiders of the Lost Ark',
#   '8.4',
#   '1M',
#   'December 10, 1981 (India)',
#   '$18,000,000 (estimated)',
#   'US & Canada',
#   '$248159971',
#   'US & Canada',
#   '$8305823',
#   'Jun 14 1981',
#   '$389,925,971'),
#  ('Das Leben der Anderen',
#   '8.4',
#   '409K',
#   'March 23, 2006 (Germany)',
#   '$2,000,000 (estimated)',
#   'US & Canada',
#   '$11286112',
#   'US & Canada',
#   '$223000',
#   'Feb 11 2007',
#   '$77,357,476'),
#  ('Sunset Blvd.',
#   '8.4',
#   '236K',
#   'August 4, 1950 (Turkey)',
#   '$1,752,000 (estimated)',
#   'US & Canada',
#   '$299645',
#   'US & Canada',
#   '$169067',
#   'May 13 2018',
#   '$304,474'),
#  ('Paths of Glory',
#   '8.4',
#   '212K',
#   'December 25, 1957 (United States)',
#   '$935,000 (estimated)',
#   'US & Canada',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$5,477'),
#  ('Avengers: Infinity War',
#   '8.4',
#   '1.2M',
#   'April 27, 2018 (India)',
#   '$321,000,000 (estimated)',
#   'US & Canada',
#   '$678815482',
#   'US & Canada',
#   '$257698183',
#   'Apr 29 2018',
#   '$2,052,415,039'),
#  ('Spider-Man: Into the Spider-Verse',
#   '8.4',
#   '667K',
#   'December 14, 2018 (India)',
#   '$90,000,000 (estimated)',
#   'US & Canada',
#   '$190241310',
#   'US & Canada',
#   '$35363376',
#   'Dec 16 2018',
#   '$384,298,736'),
#  ('The Shining',
#   '8.4',
#   '1.1M',
#   'October 4, 2017 (India)',
#   '$19,000,000 (estimated)',
#   'US & Canada',
#   '$45634352',
#   'US & Canada',
#   '$622337',
#   'May 26 1980',
#   '$47,380,008'),
#  ('Witness for the Prosecution',
#   '8.4',
#   '137K',
#   'February 6, 1958 (United States)',
#   '$3,000,000 (estimated)',
#   'US & Canada',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$7,693'),
#  ('The Great Dictator',
#   '8.4',
#   '237K',
#   'March 7, 1941 (United States)',
#   '$2,000,000 (estimated)',
#   'US & Canada',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$972,212'),
#  ('Alien 2',
#   '8.4',
#   '760K',
#   'July 11, 1987 (India)',
#   '$18,500,000 (estimated)',
#   'US & Canada',
#   '$85160248',
#   'US & Canada',
#   '$10052042',
#   'Jul 20 1986',
#   '$131,060,248'),
#  ('Inglourious Basterds',
#   '8.4',
#   '1.6M',
#   'October 2, 2009 (India)',
#   '$70,000,000 (estimated)',
#   'US & Canada',
#   '$120540719',
#   'US & Canada',
#   '$38054676',
#   'Aug 23 2009',
#   '$321,458,605'),
#  ('The Dark Knight Rises',
#   '8.4',
#   '1.8M',
#   'July 20, 2012 (India)',
#   '$250,000,000 (estimated)',
#   'US & Canada',
#   '$448149584',
#   'US & Canada',
#   '$160887295',
#   'Jul 22 2012',
#   '$1,085,289,416'),
#  ('Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   '8.4',
#   '517K',
#   'January 29, 1964 (United Kingdom)',
#   '$1,800,000 (estimated)',
#   'US & Canada',
#   '$9440272',
#   'US & Canada',
#   '$11751',
#   'Jul 17 1994',
#   '$9,529,170'),
#  ('American Beauty',
#   '8.3',
#   '1.2M',
#   'April 1, 2020 (India)',
#   '$15,000,000 (estimated)',
#   'US & Canada',
#   '$130096601',
#   'US & Canada',
#   '$861531',
#   'Sep 19 1999',
#   '$356,296,601'),
#  ('Oldeuboi',
#   '8.3',
#   '633K',
#   'October 4, 2017 (India)',
#   '$3,000,000 (estimated)',
#   'US & Canada',
#   '$2458200',
#   'US & Canada',
#   '$68957',
#   'Mar 27 2005',
#   '$17,542,965'),
#  ('Coco',
#   '8.4',
#   '587K',
#   'November 24, 2017 (India)',
#   '$175,000,000 (estimated)',
#   'US & Canada',
#   '$210460015',
#   'US & Canada',
#   '$50802605',
#   'Nov 26 2017',
#   '$814,337,054'),
#  ('Amadeus',
#   '8.4',
#   '426K',
#   'September 19, 1984 (United States)',
#   '$18,000,000 (estimated)',
#   'US & Canada',
#   '$51973029',
#   'US & Canada',
#   '$505276',
#   'Sep 23 1984',
#   '$52,068,956'),
#  ('Toy Story',
#   '8.3',
#   '1.1M',
#   'November 22, 1995 (United States)',
#   '$30,000,000 (estimated)',
#   'US & Canada',
#   '$223225679',
#   'US & Canada',
#   '$29140617',
#   'Nov 26 1995',
#   '$394,436,586'),
#  ('Das Boot',
#   '8.4',
#   '264K',
#   'February 17, 1982 (France)',
#   'DEM\xa032,000,000 (estimated)',
#   'US & Canada',
#   '$11487676',
#   'US & Canada',
#   '$26994',
#   'Feb 14 1982',
#   '$11,488,778'),
#  ('Braveheart',
#   '8.3',
#   '1.1M',
#   'June 22, 1995 (India)',
#   '$72,000,000 (estimated)',
#   'US & Canada',
#   '$75609945',
#   'US & Canada',
#   '$9938276',
#   'May 28 1995',
#   '$213,216,216'),
#  ('Avengers: Endgame',
#   '8.4',
#   '1.3M',
#   'April 26, 2019 (India)',
#   '$356,000,000 (estimated)',
#   'US & Canada',
#   '$858373000',
#   'US & Canada',
#   '$357115007',
#   'Apr 28 2019',
#   '$2,799,439,100'),
#  ('Joker',
#   '8.4',
#   '1.5M',
#   'October 2, 2019 (India)',
#   '$55,000,000 (estimated)',
#   'US & Canada',
#   '$335477657',
#   'US & Canada',
#   '$96202337',
#   'Oct 6 2019',
#   '$1,078,958,629'),
#  ('Mononoke-hime',
#   '8.3',
#   '432K',
#   'March 2, 2020 (India)',
#   '¥2,400,000,000 (estimated)',
#   'US & Canada',
#   '$4845631',
#   'US & Canada',
#   '$144446',
#   'Oct 31 1999',
#   '$170,204,201'),
#  ('Good Will Hunting',
#   '8.3',
#   '1.1M',
#   'January 9, 1998 (United States)',
#   '$10,000,000 (estimated)',
#   'US & Canada',
#   '$138433435',
#   'US & Canada',
#   '$272912',
#   'Dec 7 1997',
#   '$225,933,435'),
#  ('Kimi No Na Wa.',
#   '8.4',
#   '317K',
#   'August 26, 2016 (Japan)',
#   '¥370,000,000 (estimated)',
#   'US & Canada',
#   '$5017246',
#   'US & Canada',
#   '$1813781',
#   'Apr 9 2017',
#   '$382,238,191'),
#  ('Once Upon a Time in America',
#   '8.3',
#   '376K',
#   'June 1, 1984 (United States)',
#   '$30,000,000 (estimated)',
#   'US & Canada',
#   '$5321508',
#   'US & Canada',
#   '$2412014',
#   'Jun 3 1984',
#   '$5,475,086'),
#  ('Tengoku to Jigoku',
#   '8.4',
#   '53K',
#   'March 1, 1963 (Japan)',
#   'Not Found',
#   'US & Canada',
#   '$46808',
#   'US & Canada',
#   '$15942',
#   'Jul 28 2002',
#   '$46,808'),
#  ('3 Idiots',
#   '8.4',
#   '433K',
#   'December 25, 2009 (India)',
#   '₹550,000,000 (estimated)',
#   'US & Canada',
#   '$6532874',
#   'US & Canada',
#   '$1645502',
#   'Dec 27 2009',
#   '$60,262,836'),
#  ("Singin' in the Rain",
#   '8.3',
#   '260K',
#   'April 10, 1952 (United States)',
#   '$2,540,800 (estimated)',
#   'US & Canada',
#   '$1884537',
#   'US & Canada',
#   '$13643',
#   'Nov 10 2002',
#   '$2,008,537'),
#  ('Capharnaüm',
#   '8.4',
#   '104K',
#   'June 21, 2019 (India)',
#   '$4,000,000 (estimated)',
#   'US & Canada',
#   '$1661096',
#   'US & Canada',
#   '$24988',
#   'Dec 16 2018',
#   '$64,417,003'),
#  ('Oppenheimer',
#   '8.3',
#   '700K',
#   'July 21, 2023 (India)',
#   '$100,000,000 (estimated)',
#   'US & Canada',
#   '$329862540',
#   'US & Canada',
#   '$82455420',
#   'Jul 23 2023',
#   '$960,428,540'),
#  ('Requiem for a Dream',
#   '8.3',
#   '896K',
#   'October 4, 2017 (India)',
#   '$4,500,000 (estimated)',
#   'US & Canada',
#   '$3635482',
#   'US & Canada',
#   '$64770',
#   'Oct 8 2000',
#   '$7,390,108'),
#  ('Idi I Smotri',
#   '8.4',
#   '96K',
#   'September 3, 1985 (Philippines)',
#   'Not Found',
#   'US & Canada',
#   '$71909',
#   'US & Canada',
#   '$16053',
#   'Feb 23 2020',
#   '$20,929,648'),
#  ('Toy Story 3',
#   '8.3',
#   '890K',
#   'June 25, 2010 (India)',
#   '$200,000,000 (estimated)',
#   'US & Canada',
#   '$415004880',
#   'US & Canada',
#   '$110307189',
#   'Jun 20 2010',
#   '$1,067,316,101'),
#  ('Star Wars: Episode VI - Return of the Jedi',
#   '8.3',
#   '1.1M',
#   'December 16, 1983 (India)',
#   '$32,500,000 (estimated)',
#   'US & Canada',
#   '$316566101',
#   'US & Canada',
#   '$23019618',
#   'May 29 1983',
#   '$475,106,177'),
#  ('Eternal Sunshine of the Spotless Mind',
#   '8.3',
#   '1.1M',
#   'December 15, 2019 (India)',
#   '$20,000,000 (estimated)',
#   'US & Canada',
#   '$34400301',
#   'US & Canada',
#   '$8175198',
#   'Mar 21 2004',
#   '$73,390,334'),
#  ('Jagten',
#   '8.3',
#   '363K',
#   'January 10, 2013 (Denmark)',
#   'DKK\xa020,000,000 (estimated)',
#   'US & Canada',
#   '$613308',
#   'US & Canada',
#   '$43045',
#   'Jul 14 2013',
#   '$15,886,373'),
#  ('2001: A Space Odyssey',
#   '8.3',
#   '717K',
#   'October 4, 2017 (India)',
#   '$12,000,000 (estimated)',
#   'US & Canada',
#   '$60481243',
#   'US & Canada',
#   '$202759',
#   'May 20 2018',
#   '$66,543,782'),
#  ('Reservoir Dogs',
#   '8.3',
#   '1.1M',
#   'September 2, 1992 (India)',
#   '$1,200,000 (estimated)',
#   'US & Canada',
#   '$2832029',
#   'US & Canada',
#   '$147839',
#   'Oct 25 1992',
#   '$2,930,208'),
#  ('Ikiru',
#   '8.3',
#   '87K',
#   'October 9, 1952 (Japan)',
#   'Not Found',
#   'US & Canada',
#   '$60239',
#   'US & Canada',
#   '$2149',
#   'Dec 29 2002',
#   '$96,302'),
#  ('Lawrence of Arabia',
#   '8.3',
#   '313K',
#   'July 30, 2016 (India)',
#   '$15,000,000 (estimated)',
#   'US & Canada',
#   '$45306425',
#   'US & Canada',
#   '$20846',
#   'Sep 22 2002',
#   '$45,744,187'),
#  ('The Apartment',
#   '8.3',
#   '196K',
#   'June 29, 1960 (Canada)',
#   '$3,000,000 (estimated)',
#   'US & Canada',
#   '$18600000',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$18,778,738'),
#  ('North by Northwest',
#   '8.3',
#   '345K',
#   'December 18, 1959 (United States)',
#   '$3,101,000 (estimated)',
#   'US & Canada',
#   '$66728',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$149,561'),
#  ('Citizen Kane',
#   '8.3',
#   '465K',
#   'October 13, 2020 (India)',
#   '$839,727 (estimated)',
#   'US & Canada',
#   '$1627530',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$1,702,325'),
#  ('Vertigo',
#   '8.3',
#   '426K',
#   'October 30, 2014 (India)',
#   '$2,479,000 (estimated)',
#   'US & Canada',
#   '$7705225',
#   'US & Canada',
#   '$252880',
#   'Mar 18 2018',
#   '$7,804,803'),
#  ('M - Eine Stadt sucht einen Mörder',
#   '8.3',
#   '168K',
#   'August 31, 1931 (Sweden)',
#   'Not Found',
#   'US & Canada',
#   '$35566',
#   'US & Canada',
#   '$6123',
#   'Mar 17 2013',
#   '$35,566'),
#  ('Incendies',
#   '8.3',
#   '198K',
#   'September 12, 2020 (India)',
#   '$6,800,000 (estimated)',
#   'US & Canada',
#   '$2071334',
#   'US & Canada',
#   '$50679',
#   'Apr 24 2011',
#   '$6,797,861'),
#  ('Double Indemnity',
#   '8.3',
#   '167K',
#   'July 6, 1944 (United States)',
#   '$927,262 (estimated)',
#   'US & Canada',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$19,324'),
#  ('Scarface',
#   '8.3',
#   '913K',
#   '1990 (India)',
#   '$25,000,000 (estimated)',
#   'US & Canada',
#   '$45967303',
#   'US & Canada',
#   '$4597536',
#   'Dec 11 1983',
#   '$66,443,303'),
#  ("Le fabuleux destin d'Amélie Poulain",
#   '8.3',
#   '793K',
#   'April 25, 2001 (France)',
#   '$10,000,000 (estimated)',
#   'US & Canada',
#   '$33711390',
#   'US & Canada',
#   '$136470',
#   'Nov 4 2001',
#   '$174,918,005'),
#  ('Full Metal Jacket',
#   '8.3',
#   '788K',
#   'July 10, 1987 (United States)',
#   '$30,000,000 (estimated)',
#   'US & Canada',
#   '$46357676',
#   'US & Canada',
#   '$2217307',
#   'Jun 28 1987',
#   '$46,361,894'),
#  ('A Clockwork Orange',
#   '8.3',
#   '879K',
#   'October 4, 2017 (India)',
#   '$2,200,000 (estimated)',
#   'US & Canada',
#   '$26617553',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$27,023,100'),
#  ('Heat',
#   '8.3',
#   '717K',
#   'December 15, 1995 (United States)',
#   '$60,000,000 (estimated)',
#   'US & Canada',
#   '$67436818',
#   'US & Canada',
#   '$8445656',
#   'Dec 17 1995',
#   '$187,436,818'),
#  ('Up',
#   '8.3',
#   '1.1M',
#   'September 11, 2009 (India)',
#   '$175,000,000 (estimated)',
#   'US & Canada',
#   '$293004164',
#   'US & Canada',
#   '$68108790',
#   'May 31 2009',
#   '$735,102,136'),
#  ('To Kill a Mockingbird',
#   '8.3',
#   '332K',
#   'March 6, 1963 (India)',
#   '$2,000,000 (estimated)',
#   'US & Canada',
#   '$592237',
#   'US & Canada',
#   '$357549',
#   'Mar 24 2019',
#   '$599,146'),
#  ('The Sting',
#   '8.3',
#   '279K',
#   'December 25, 1973 (United States)',
#   '$5,500,000 (estimated)',
#   'US & Canada',
#   '$156000000',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$156,000,000'),
#  ('Jodaeiye Nader Az Simin',
#   '8.3',
#   '258K',
#   'October 29, 2012 (India)',
#   '$500,000 (estimated)',
#   'US & Canada',
#   '$7099055',
#   'US & Canada',
#   '$59481',
#   'Jan 1 2012',
#   '$22,926,076'),
#  ('Indiana Jones and the Last Crusade',
#   '8.2',
#   '809K',
#   'July 26, 1990 (India)',
#   '$48,000,000 (estimated)',
#   'US & Canada',
#   '$197171806',
#   'US & Canada',
#   '$29355021',
#   'May 28 1989',
#   '$474,171,806'),
#  ('Die Hard',
#   '8.2',
#   '942K',
#   'February 14, 2013 (India)',
#   '$28,000,000 (estimated)',
#   'US & Canada',
#   '$85892546',
#   'US & Canada',
#   '$601851',
#   'Jul 17 1988',
#   '$143,651,650'),
#  ('Metropolis',
#   '8.3',
#   '185K',
#   'February 6, 1927 (France)',
#   'DEM\xa06,000,000 (estimated)',
#   'US & Canada',
#   '$1236166',
#   'US & Canada',
#   '$19386',
#   'Jul 14 2002',
#   '$1,349,711'),
#  ('Taare Zameen Par',
#   '8.3',
#   '206K',
#   'December 21, 2007 (India)',
#   'Not Found',
#   'US & Canada',
#   '$1223869',
#   'US & Canada',
#   '$352568',
#   'Dec 23 2007',
#   '$21,897,373'),
#  ('Hamilton',
#   '8.3',
#   '113K',
#   'July 3, 2020 (India)',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   None),
#  ('Snatch',
#   '8.2',
#   '907K',
#   'October 31, 2019 (India)',
#   '£6,000,000 (estimated)',
#   'US & Canada',
#   '$30328156',
#   'US & Canada',
#   '$27932',
#   'Dec 10 2000',
#   '$83,557,872'),
#  ('L.A. Confidential',
#   '8.2',
#   '616K',
#   'September 19, 1997 (United States)',
#   '$35,000,000 (estimated)',
#   'US & Canada',
#   '$64616940',
#   'US & Canada',
#   '$5211198',
#   'Sep 21 1997',
#   '$126,216,940'),
#  ('Ladri Di Biciclette',
#   '8.3',
#   '175K',
#   'November 24, 1948 (Italy)',
#   '$133,000 (estimated)',
#   'US & Canada',
#   '$371111',
#   'US & Canada',
#   '$25377',
#   'Oct 4 1998',
#   '$450,159'),
#  ('1917',
#   '8.2',
#   '671K',
#   'January 17, 2020 (India)',
#   '$95,000,000 (estimated)',
#   'US & Canada',
#   '$159227644',
#   'US & Canada',
#   '$576216',
#   'Dec 29 2019',
#   '$384,580,017'),
#  ('Taxi Driver',
#   '8.2',
#   '917K',
#   'March 13, 1978 (India)',
#   '$1,300,000 (estimated)',
#   'US & Canada',
#   '$28262574',
#   'US & Canada',
#   '$116458',
#   'Feb 19 1996',
#   '$28,579,560'),
#  ('Der Untergang',
#   '8.2',
#   '374K',
#   'July 4, 2006 (India)',
#   '€13,500,000 (estimated)',
#   'US & Canada',
#   '$5509040',
#   'US & Canada',
#   '$18195',
#   'Feb 20 2005',
#   '$92,181,574'),
#  ('Dangal',
#   '8.3',
#   '209K',
#   'December 23, 2016 (India)',
#   '₹700,000,000 (estimated)',
#   'US & Canada',
#   '$12391761',
#   'US & Canada',
#   '$3248481',
#   'Dec 25 2016',
#   '$303,723,636'),
#  ('Per qualche dollaro in più',
#   '8.2',
#   '274K',
#   'July 1, 2023 (Italy)',
#   '$600,000 (estimated)',
#   'US & Canada',
#   '$15000000',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$15,000,000'),
#  ('Batman Begins',
#   '8.2',
#   '1.6M',
#   'June 17, 2005 (India)',
#   '$150,000,000 (estimated)',
#   'US & Canada',
#   '$206863479',
#   'US & Canada',
#   '$48745440',
#   'Jun 19 2005',
#   '$375,325,692'),
#  ('The Wolf of Wall Street',
#   '8.2',
#   '1.6M',
#   'January 3, 2014 (India)',
#   '$100,000,000 (estimated)',
#   'US & Canada',
#   '$116900694',
#   'US & Canada',
#   '$18361578',
#   'Dec 29 2013',
#   '$407,039,432'),
#  ('Some Like It Hot',
#   '8.2',
#   '283K',
#   'March 19, 1959 (United States)',
#   '$2,883,848 (estimated)',
#   'US & Canada',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$200,234'),
#  ('The Kid',
#   '8.2',
#   '134K',
#   'October 7, 2015 (India)',
#   '$250,000 (estimated)',
#   'US & Canada',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$41,979'),
#  ('Green Book',
#   '8.2',
#   '566K',
#   'November 21, 2018 (India)',
#   '$23,000,000 (estimated)',
#   'US & Canada',
#   '$85080171',
#   'US & Canada',
#   '$320429',
#   'Nov 18 2018',
#   '$321,752,656'),
#  ('The Father',
#   '8.2',
#   '191K',
#   'April 23, 2021 (India)',
#   '$6,000,000 (estimated)',
#   'US & Canada',
#   '$2122771',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$24,048,935'),
#  ('Judgment at Nuremberg',
#   '8.3',
#   '85K',
#   'December 18, 1961 (Sweden)',
#   '$3,000,000 (estimated)',
#   'US & Canada',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$12,180'),
#  ('All About Eve',
#   '8.2',
#   '138K',
#   'May 1, 1951 (India)',
#   '$1,400,000 (estimated)',
#   'US & Canada',
#   '$63463',
#   'US & Canada',
#   '$10177',
#   'Oct 8 2000',
#   '$152,366'),
#  ('The Truman Show',
#   '8.2',
#   '1.2M',
#   'November 14, 1998 (India)',
#   '$60,000,000 (estimated)',
#   'US & Canada',
#   '$125618201',
#   'US & Canada',
#   '$31542121',
#   'Jun 7 1998',
#   '$264,118,712'),
#  ('Top Gun: Maverick',
#   '8.2',
#   '688K',
#   'May 27, 2022 (India)',
#   '$170,000,000 (estimated)',
#   'US & Canada',
#   '$718732821',
#   'US & Canada',
#   '$126707459',
#   'May 29 2022',
#   '$1,495,696,292'),
#  ('Shutter Island',
#   '8.2',
#   '1.4M',
#   'June 4, 2010 (India)',
#   '$80,000,000 (estimated)',
#   'US & Canada',
#   '$128012934',
#   'US & Canada',
#   '$41062440',
#   'Feb 21 2010',
#   '$294,850,027'),
#  ('There Will Be Blood',
#   '8.2',
#   '639K',
#   'January 30, 2008 (India)',
#   '$25,000,000 (estimated)',
#   'US & Canada',
#   '$40222514',
#   'US & Canada',
#   '$190739',
#   'Dec 30 2007',
#   '$76,186,224'),
#  ('Casino',
#   '8.2',
#   '562K',
#   'July 3, 2013 (India)',
#   '$52,000,000 (estimated)',
#   'US & Canada',
#   '$42512375',
#   'US & Canada',
#   '$9946480',
#   'Nov 26 1995',
#   '$116,112,375'),
#  ('Ran',
#   '8.2',
#   '136K',
#   'June 1, 1985 (Japan)',
#   '$11,500,000 (estimated)',
#   'US & Canada',
#   '$4135750',
#   'US & Canada',
#   '$3567',
#   'Jul 2 2000',
#   '$4,166,319'),
#  ('Jurassic Park',
#   '8.2',
#   '1.1M',
#   'April 15, 1994 (India)',
#   '$63,000,000 (estimated)',
#   'US & Canada',
#   '$407185075',
#   'US & Canada',
#   '$47026828',
#   'Jun 13 1993',
#   '$1,114,456,337'),
#  ('The Sixth Sense',
#   '8.2',
#   '1M',
#   'May 21, 2019 (India)',
#   '$40,000,000 (estimated)',
#   'US & Canada',
#   '$293506292',
#   'US & Canada',
#   '$26681262',
#   'Aug 8 1999',
#   '$672,806,432'),
#  ('El Laberinto Del Fauno',
#   '8.2',
#   '701K',
#   'August 6, 2018 (India)',
#   '$19,000,000 (estimated)',
#   'US & Canada',
#   '$37646380',
#   'US & Canada',
#   '$568641',
#   'Dec 31 2006',
#   '$83,863,565'),
#  ('Unforgiven',
#   '8.2',
#   '435K',
#   'October 9, 2020 (India)',
#   '$14,400,000 (estimated)',
#   'US & Canada',
#   '$101167799',
#   'US & Canada',
#   '$15018007',
#   'Aug 9 1992',
#   '$159,167,799'),
#  ('No Country for Old Men',
#   '8.2',
#   '1.1M',
#   'January 18, 2008 (India)',
#   '$25,000,000 (estimated)',
#   'US & Canada',
#   '$74283625',
#   'US & Canada',
#   '$1202000',
#   'Nov 11 2007',
#   '$171,632,777'),
#  ('A Beautiful Mind',
#   '8.2',
#   '984K',
#   'October 9, 2020 (India)',
#   '$58,000,000 (estimated)',
#   'US & Canada',
#   '$170742341',
#   'US & Canada',
#   '$367151',
#   'Dec 23 2001',
#   '$316,791,257'),
#  ('The Thing',
#   '8.2',
#   '465K',
#   'December 10, 1982 (India)',
#   '$15,000,000 (estimated)',
#   'US & Canada',
#   '$19857465',
#   'US & Canada',
#   '$3107897',
#   'Jun 27 1982',
#   '$19,872,469'),
#  ('The Treasure of the Sierra Madre',
#   '8.2',
#   '132K',
#   'January 24, 1948 (United States)',
#   '$3,000,000 (estimated)',
#   'US & Canada',
#   '$5014000',
#   'US & Canada',
#   '$144074',
#   'Jan 14 2018',
#   '$5,014,000'),
#  ('Kill Bill: Vol. 1',
#   '8.2',
#   '1.2M',
#   'October 10, 2003 (United States)',
#   '$30,000,000 (estimated)',
#   'US & Canada',
#   '$70099045',
#   'US & Canada',
#   '$22200000',
#   'Oct 12 2003',
#   '$180,908,413'),
#  ('Yojimbo',
#   '8.2',
#   '131K',
#   'April 25, 1961 (Japan)',
#   'Not Found',
#   'US & Canada',
#   '$46808',
#   'US & Canada',
#   '$15942',
#   'Jul 28 2002',
#   '$46,808'),
#  ('Monty Python and the Holy Grail',
#   '8.2',
#   '569K',
#   'December 6, 1979 (India)',
#   '£229,575 (estimated)',
#   'US & Canada',
#   '$2562392',
#   'US & Canada',
#   '$45487',
#   'Jun 17 2001',
#   '$2,812,669'),
#  ('The Great Escape',
#   '8.2',
#   '258K',
#   'July 4, 1963 (United States)',
#   '$4,000,000 (estimated)',
#   'US & Canada',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$230,637'),
#  ('Finding Nemo',
#   '8.2',
#   '1.1M',
#   'October 24, 2003 (India)',
#   '$94,000,000 (estimated)',
#   'US & Canada',
#   '$380843261',
#   'US & Canada',
#   '$70251710',
#   'Jun 1 2003',
#   '$941,637,960'),
#  ('Rashōmon',
#   '8.2',
#   '180K',
#   'August 26, 1950 (Japan)',
#   '$250,000 (estimated)',
#   'US & Canada',
#   '$46808',
#   'US & Canada',
#   '$15942',
#   'Jul 28 2002',
#   '$117,668'),
#  ('Prisoners',
#   '8.2',
#   '805K',
#   'September 27, 2013 (India)',
#   '$46,000,000 (estimated)',
#   'US & Canada',
#   '$61002302',
#   'US & Canada',
#   '$20817053',
#   'Sep 22 2013',
#   '$122,127,446'),
#  ('Hauru No Ugoku Shiro',
#   '8.2',
#   '446K',
#   'April 1, 2020 (India)',
#   '$24,000,000 (estimated)',
#   'US & Canada',
#   '$6789268',
#   'US & Canada',
#   '$427987',
#   'Jun 12 2005',
#   '$237,728,734'),
#  ('The Elephant Man',
#   '8.2',
#   '258K',
#   '1983 (India)',
#   '$5,000,000 (estimated)',
#   'US & Canada',
#   '$26010864',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$26,028,672'),
#  ('Chinatown',
#   '8.1',
#   '349K',
#   'February 9, 2013 (India)',
#   '$6,000,000 (estimated)',
#   'US & Canada',
#   '$29200000',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$29,227,645'),
#  ('Dial M for Murder',
#   '8.2',
#   '188K',
#   'July 24, 2020 (India)',
#   '$1,400,000 (estimated)',
#   'US & Canada',
#   '$24845',
#   'US & Canada',
#   '$12562',
#   'Apr 11 1999',
#   '$43,308'),
#  ('Gone with the Wind',
#   '8.2',
#   '333K',
#   'July 8, 2020 (India)',
#   '$3,977,000 (estimated)',
#   'US & Canada',
#   '$200882193',
#   'US & Canada',
#   '$1192593',
#   'Jun 28 1998',
#   '$402,382,193'),
#  ('V for Vendetta',
#   '8.2',
#   '1.2M',
#   'October 4, 2017 (India)',
#   '$54,000,000 (estimated)',
#   'US & Canada',
#   '$70511035',
#   'US & Canada',
#   '$25642340',
#   'Mar 19 2006',
#   '$134,686,457'),
#  ('Lock, Stock and Two Smoking Barrels',
#   '8.1',
#   '615K',
#   'August 28, 1998 (United Kingdom)',
#   '£960,000 (estimated)',
#   'US & Canada',
#   '$3753929',
#   'US & Canada',
#   '$143321',
#   'Mar 7 1999',
#   '$3,753,929'),
#  ('El Secreto De Sus Ojos',
#   '8.2',
#   '222K',
#   'August 13, 2009 (Argentina)',
#   '$2,000,000 (estimated)',
#   'US & Canada',
#   '$6391436',
#   'US & Canada',
#   '$167866',
#   'Apr 18 2010',
#   '$35,079,650'),
#  ('Inside Out',
#   '8.1',
#   '782K',
#   'June 26, 2015 (India)',
#   '$175,000,000 (estimated)',
#   'US & Canada',
#   '$356921711',
#   'US & Canada',
#   '$90440272',
#   'Jun 21 2015',
#   '$858,852,998'),
#  ('Raging Bull',
#   '8.1',
#   '379K',
#   'December 19, 1980 (United States)',
#   '$18,000,000 (estimated)',
#   'US & Canada',
#   '$23383987',
#   'US & Canada',
#   '$128590',
#   'Nov 16 1980',
#   '$23,406,933'),
#  ('Three Billboards Outside Ebbing, Missouri',
#   '8.1',
#   '553K',
#   'February 23, 2018 (India)',
#   '$15,000,000 (estimated)',
#   'US & Canada',
#   '$54513740',
#   'US & Canada',
#   '$322168',
#   'Nov 12 2017',
#   '$162,729,321'),
#  ('Trainspotting',
#   '8.1',
#   '724K',
#   'February 23, 1996 (United Kingdom)',
#   '£1,500,000 (estimated)',
#   'US & Canada',
#   '$16491080',
#   'US & Canada',
#   '$262673',
#   'Jul 21 1996',
#   '$16,787,952'),
#  ('The Bridge on the River Kwai',
#   '8.1',
#   '233K',
#   'December 28, 1957 (India)',
#   '$3,000,000 (estimated)',
#   'US & Canada',
#   '$27200000',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$27,200,463'),
#  ('Spider-Man: No Way Home',
#   '8.2',
#   '873K',
#   'December 16, 2021 (India)',
#   '$200,000,000 (estimated)',
#   'US & Canada',
#   '$814115070',
#   'US & Canada',
#   '$260138569',
#   'Dec 19 2021',
#   '$1,921,847,111'),
#  ('Fargo',
#   '8.1',
#   '724K',
#   'April 5, 1996 (United States)',
#   '$7,000,000 (estimated)',
#   'US & Canada',
#   '$24611975',
#   'US & Canada',
#   '$730265',
#   'Mar 10 1996',
#   '$60,611,975'),
#  ('Klaus',
#   '8.2',
#   '189K',
#   'November 16, 2019 (India)',
#   '$40,000,000 (estimated)',
#   'US & Canada',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   None),
#  ('Warrior',
#   '8.1',
#   '497K',
#   'October 31, 2015 (India)',
#   '$25,000,000 (estimated)',
#   'US & Canada',
#   '$13657115',
#   'US & Canada',
#   '$5242107',
#   'Sep 11 2011',
#   '$23,308,615'),
#  ('Catch Me If You Can',
#   '8.1',
#   '1.1M',
#   'April 30, 2020 (India)',
#   '$52,000,000 (estimated)',
#   'US & Canada',
#   '$164615351',
#   'US & Canada',
#   '$30053627',
#   'Dec 29 2002',
#   '$352,114,312'),
#  ('Godzilla Minus One',
#   '8.3',
#   '47K',
#   'November 3, 2023 (Japan)',
#   '$15,000,000 (estimated)',
#   'US & Canada',
#   '$56418793',
#   'US & Canada',
#   '$11419975',
#   'Dec 3 2023',
#   '$112,795,473'),
#  ('Gran Torino',
#   '8.1',
#   '813K',
#   'March 13, 2009 (India)',
#   '$33,000,000 (estimated)',
#   'US & Canada',
#   '$148095302',
#   'US & Canada',
#   '$271720',
#   'Dec 14 2008',
#   '$269,958,228'),
#  ('My Neighbour Totoro',
#   '8.1',
#   '378K',
#   'February 1, 2020 (India)',
#   '$3,700,000 (estimated)',
#   'US & Canada',
#   '$2250213',
#   'US & Canada',
#   '$539245',
#   'Sep 30 2018',
#   '$30,695,952'),
#  ('Million Dollar Baby',
#   '8.1',
#   '720K',
#   'March 11, 2005 (India)',
#   '$30,000,000 (estimated)',
#   'US & Canada',
#   '$100492203',
#   'US & Canada',
#   '$179953',
#   'Dec 19 2004',
#   '$216,763,646'),
#  ('Harry Potter and the Deathly Hallows: Part 2',
#   '8.1',
#   '945K',
#   'July 15, 2011 (India)',
#   '$125,000,000 (estimated)',
#   'US & Canada',
#   '$381447587',
#   'US & Canada',
#   '$169189427',
#   'Jul 17 2011',
#   '$1,356,962,211'),
#  ('Bacheha-Ye Aseman',
#   '8.2',
#   '80K',
#   '1997 (Iran)',
#   '$180,000 (estimated)',
#   'US & Canada',
#   '$933933',
#   'US & Canada',
#   '$20100',
#   'Jan 24 1999',
#   '$933,933'),
#  ('12 Years a Slave',
#   '8.1',
#   '740K',
#   'January 31, 2014 (India)',
#   '$20,000,000 (estimated)',
#   'US & Canada',
#   '$56671993',
#   'US & Canada',
#   '$923715',
#   'Oct 20 2013',
#   '$187,734,091'),
#  ('Blade Runner',
#   '8.1',
#   '821K',
#   'June 25, 2020 (India)',
#   '$28,000,000 (estimated)',
#   'US & Canada',
#   '$32914489',
#   'US & Canada',
#   '$6150002',
#   'Jun 27 1982',
#   '$41,753,783'),
#  ('Before Sunrise',
#   '8.1',
#   '338K',
#   'December 9, 2019 (India)',
#   '$2,500,000 (estimated)',
#   'US & Canada',
#   '$5535405',
#   'US & Canada',
#   '$1423537',
#   'Jan 29 1995',
#   '$5,992,863'),
#  ('Ben-Hur',
#   '8.1',
#   '253K',
#   'November 18, 1959 (Canada)',
#   '$15,000,000 (estimated)',
#   'US & Canada',
#   '$74432704',
#   'US & Canada',
#   '$241792',
#   'Apr 14 2019',
#   '$74,437,981'),
#  ('The Grand Budapest Hotel',
#   '8.1',
#   '883K',
#   'July 25, 2014 (India)',
#   '$25,000,000 (estimated)',
#   'US & Canada',
#   '$59301324',
#   'US & Canada',
#   '$811166',
#   'Mar 9 2014',
#   '$174,567,384'),
#  ('Barry Lyndon',
#   '8.1',
#   '182K',
#   '1977 (India)',
#   '$11,000,000 (estimated)',
#   'US & Canada',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$260,131'),
#  ('Gone Girl',
#   '8.1',
#   '1.1M',
#   'October 31, 2014 (India)',
#   '$61,000,000 (estimated)',
#   'US & Canada',
#   '$167767189',
#   'US & Canada',
#   '$37513109',
#   'Oct 5 2014',
#   '$369,330,536'),
#  ('Hacksaw Ridge',
#   '8.1',
#   '591K',
#   'December 16, 2016 (India)',
#   '$40,000,000 (estimated)',
#   'US & Canada',
#   '$67209615',
#   'US & Canada',
#   '$15190758',
#   'Nov 6 2016',
#   '$180,563,636'),
#  ('The Gold Rush',
#   '8.1',
#   '118K',
#   'August 16, 1925 (United States)',
#   '$923,000 (estimated)',
#   'US & Canada',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$31,490'),
#  ('In the Name of the Father',
#   '8.1',
#   '187K',
#   'December 27, 1993 (Ireland)',
#   '$13,000,000 (estimated)',
#   'US & Canada',
#   '$25096862',
#   'US & Canada',
#   '$109805',
#   'Jan 2 1994',
#   '$65,796,862'),
#  ('Salinui Chueok',
#   '8.1',
#   '215K',
#   'May 2, 2003 (South Korea)',
#   '$2,800,000 (estimated)',
#   'US & Canada',
#   '$15357',
#   'US & Canada',
#   '$4487',
#   'Jul 17 2005',
#   '$1,208,481'),
#  ('Dead Poets Society',
#   '8.1',
#   '543K',
#   'February 15, 2021 (India)',
#   '$16,400,000 (estimated)',
#   'US & Canada',
#   '$95860116',
#   'US & Canada',
#   '$340456',
#   'Jun 4 1989',
#   '$235,860,116'),
#  ('On the Waterfront',
#   '8.1',
#   '164K',
#   'October 12, 1954 (India)',
#   '$910,000 (estimated)',
#   'US & Canada',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$2,719'),
#  ('The Deer Hunter',
#   '8.1',
#   '361K',
#   'February 23, 1979 (United States)',
#   '$15,000,000 (estimated)',
#   'US & Canada',
#   '$48979328',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$49,080,126'),
#  ('The General',
#   '8.1',
#   '98K',
#   'January 2, 1927 (United States)',
#   '$750,000 (estimated)',
#   'US & Canada',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$612'),
#  ('Relatos Salvajes',
#   '8.1',
#   '215K',
#   'August 21, 2014 (Argentina)',
#   '$3,300,000 (estimated)',
#   'US & Canada',
#   '$3106530',
#   'US & Canada',
#   '$85100',
#   'Feb 22 2015',
#   '$31,478,893'),
#  ('Mad Max: Fury Road',
#   '8.1',
#   '1.1M',
#   'May 15, 2015 (India)',
#   '$150,000,000 (estimated)',
#   'US & Canada',
#   '$154280290',
#   'US & Canada',
#   '$45428128',
#   'May 17 2015',
#   '$380,418,444'),
#  ('Monsters, Inc.',
#   '8.1',
#   '975K',
#   'June 23, 2002 (India)',
#   '$115,000,000 (estimated)',
#   'US & Canada',
#   '$290642256',
#   'US & Canada',
#   '$62577067',
#   'Nov 4 2001',
#   '$579,723,768'),
#  ('Sherlock Jr.',
#   '8.2',
#   '57K',
#   'May 11, 1924 (United States)',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$399'),
#  ('The Third Man',
#   '8.1',
#   '181K',
#   'September 3, 1949 (Turkey)',
#   'Not Found',
#   'US & Canada',
#   '$1067364',
#   'US & Canada',
#   '$13576',
#   'May 9 1999',
#   '$1,233,079'),
#  ('Smultronstället',
#   '8.1',
#   '115K',
#   'December 26, 1957 (Sweden)',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$60,418'),
#  ('Le Salaire De La Peur',
#   '8.2',
#   '66K',
#   'September 23, 1955 (India)',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$1,098'),
#  ('Jaws',
#   '8.1',
#   '657K',
#   'December 26, 1975 (India)',
#   '$7,000,000 (estimated)',
#   'US & Canada',
#   '$266567580',
#   'US & Canada',
#   '$7061513',
#   'Jun 22 1975',
#   '$477,220,580'),
#  ('How to Train Your Dragon',
#   '8.1',
#   '797K',
#   'April 16, 2010 (India)',
#   '$165,000,000 (estimated)',
#   'US & Canada',
#   '$217581231',
#   'US & Canada',
#   '$43732319',
#   'Mar 28 2010',
#   '$494,879,860'),
#  ('Mary and Max',
#   '8.1',
#   '186K',
#   'April 9, 2009 (Australia)',
#   'A$8,240,000 (estimated)',
#   'US & Canada',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$1,740,625'),
#  ('Mr. Smith Goes to Washington',
#   '8.1',
#   '121K',
#   'October 19, 1939 (United States)',
#   '$1,900,000 (estimated)',
#   'US & Canada',
#   '$144738',
#   'US & Canada',
#   '$83205',
#   'Oct 14 2018',
#   '$145,941'),
#  ('Ratatouille',
#   '8.1',
#   '820K',
#   'August 24, 2007 (India)',
#   '$150,000,000 (estimated)',
#   'US & Canada',
#   '$206445654',
#   'US & Canada',
#   '$47027395',
#   'Jul 1 2007',
#   '$623,728,318'),
#  ('Ford v. Ferrari',
#   '8.1',
#   '468K',
#   'November 15, 2019 (India)',
#   '$97,600,000 (estimated)',
#   'US & Canada',
#   '$117624357',
#   'US & Canada',
#   '$31474958',
#   'Nov 17 2019',
#   '$225,508,210'),
#  ('The Big Lebowski',
#   '8.1',
#   '858K',
#   'December 21, 2019 (India)',
#   '$15,000,000 (estimated)',
#   'US & Canada',
#   '$19301403',
#   'US & Canada',
#   '$5533844',
#   'Mar 8 1998',
#   '$48,066,229'),
#  ('Det Sjunde Inseglet',
#   '8.1',
#   '198K',
#   'February 16, 1957 (Sweden)',
#   '$150,000 (estimated)',
#   'US & Canada',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$311,212'),
#  ('Room',
#   '8.1',
#   '449K',
#   'January 29, 2016 (India)',
#   '$13,000,000 (estimated)',
#   'US & Canada',
#   '$14677654',
#   'US & Canada',
#   '$118298',
#   'Oct 18 2015',
#   '$35,402,766'),
#  ('Tokyo Story',
#   '8.1',
#   '68K',
#   'November 3, 1953 (Japan)',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$88,647'),
#  ('Rocky',
#   '8.1',
#   '626K',
#   'December 3, 1976 (United States)',
#   '$960,000 (estimated)',
#   'US & Canada',
#   '$117235147',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$117,251,948'),
#  ('Logan',
#   '8.1',
#   '828K',
#   'March 3, 2017 (India)',
#   '$97,000,000 (estimated)',
#   'US & Canada',
#   '$226277068',
#   'US & Canada',
#   '$88411916',
#   'Mar 5 2017',
#   '$619,180,476'),
#  ('Spotlight',
#   '8.1',
#   '501K',
#   'February 19, 2016 (India)',
#   '$20,000,000 (estimated)',
#   'US & Canada',
#   '$45055776',
#   'US & Canada',
#   '$295009',
#   'Nov 8 2015',
#   '$98,690,254'),
#  ('Hotel Rwanda',
#   '8.1',
#   '371K',
#   'February 4, 2005 (United States)',
#   '$17,500,000 (estimated)',
#   'US & Canada',
#   '$23530892',
#   'US & Canada',
#   '$100091',
#   'Dec 26 2004',
#   '$33,882,243'),
#  ('Platoon',
#   '8.1',
#   '438K',
#   'February 13, 1989 (India)',
#   '$6,000,000 (estimated)',
#   'US & Canada',
#   '$138530565',
#   'US & Canada',
#   '$241080',
#   'Dec 21 1986',
#   '$138,545,632'),
#  ('The Terminator',
#   '8.1',
#   '921K',
#   'October 26, 1984 (United States)',
#   '$6,400,000 (estimated)',
#   'US & Canada',
#   '$38371200',
#   'US & Canada',
#   '$4020663',
#   'Oct 28 1984',
#   '$78,371,200'),
#  ("La passion de Jeanne d'Arc",
#   '8.1',
#   '60K',
#   'October 25, 1928 (France)',
#   'Not Found',
#   'US & Canada',
#   '$21877',
#   'US & Canada',
#   '$6408',
#   'Nov 26 2017',
#   '$22,731'),
#  ('Before Sunset',
#   '8.1',
#   '287K',
#   'July 30, 2004 (United States)',
#   '$2,700,000 (estimated)',
#   'US & Canada',
#   '$5820649',
#   'US & Canada',
#   '$219425',
#   'Jul 4 2004',
#   '$15,854,926'),
#  ('La haine',
#   '8.1',
#   '195K',
#   'June 25, 1996 (India)',
#   '€2,590,000 (estimated)',
#   'US & Canada',
#   '$280859',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$414,607'),
#  ('The Best Years of Our Lives',
#   '8.1',
#   '70K',
#   'May 29, 1947 (Mexico)',
#   '$2,100,000 (estimated)',
#   'US & Canada',
#   '$23650000',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$23,661,347'),
#  ('The Exorcist',
#   '8.1',
#   '453K',
#   'August 27, 1977 (India)',
#   '$11,000,000 (estimated)',
#   'US & Canada',
#   '$233005644',
#   'US & Canada',
#   '$8175666',
#   'Sep 24 2000',
#   '$441,306,145'),
#  ('Pirates of the Caribbean: The Curse of the Black Pearl',
#   '8.1',
#   '1.2M',
#   'August 15, 2003 (India)',
#   '$140,000,000 (estimated)',
#   'US & Canada',
#   '$305413918',
#   'US & Canada',
#   '$46630690',
#   'Jul 13 2003',
#   '$654,264,546'),
#  ('Jai Bhim',
#   '8.7',
#   '217K',
#   'November 2, 2021 (India)',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   None),
#  ('Rush',
#   '8.1',
#   '512K',
#   'September 20, 2013 (India)',
#   '$38,000,000 (estimated)',
#   'US & Canada',
#   '$26947624',
#   'US & Canada',
#   '$187289',
#   'Sep 22 2013',
#   '$96,992,516'),
#  ('Network',
#   '8.1',
#   '170K',
#   'November 27, 1976 (United States)',
#   '$3,800,000 (estimated)',
#   'US & Canada',
#   '$23689877',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$23,692,346'),
#  ('Stand by Me',
#   '8.1',
#   '440K',
#   '1987 (India)',
#   '$8,000,000 (estimated)',
#   'US & Canada',
#   '$52287414',
#   'US & Canada',
#   '$242795',
#   'Aug 10 1986',
#   '$52,290,509'),
#  ('The Wizard of Oz',
#   '8.1',
#   '427K',
#   'January 6, 1952 (India)',
#   '$2,777,000 (estimated)',
#   'US & Canada',
#   '$24668669',
#   'US & Canada',
#   '$5354311',
#   'Nov 8 1998',
#   '$25,637,669'),
#  ('The Incredibles',
#   '8.0',
#   '805K',
#   'November 5, 2004 (United States)',
#   '$92,000,000 (estimated)',
#   'US & Canada',
#   '$261441092',
#   'US & Canada',
#   '$70467623',
#   'Nov 7 2004',
#   '$631,686,750'),
#  ("Hachi: A Dog's Tale",
#   '8.1',
#   '310K',
#   'October 4, 2017 (India)',
#   '$16,000,000 (estimated)',
#   'US & Canada',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$46,749,646'),
#  ('Ah-ga-ssi',
#   '8.1',
#   '171K',
#   'August 25, 2016 (India)',
#   '₩10,000,000,000 (estimated)',
#   'US & Canada',
#   '$2006788',
#   'US & Canada',
#   '$92129',
#   'Oct 23 2016',
#   '$37,863,670'),
#  ('Into the Wild',
#   '8.1',
#   '656K',
#   'July 31, 2018 (India)',
#   '$15,000,000 (estimated)',
#   'US & Canada',
#   '$18354356',
#   'US & Canada',
#   '$212440',
#   'Sep 23 2007',
#   '$56,676,733'),
#  ('My Father and My Son',
#   '8.2',
#   '92K',
#   'November 18, 2005 (Turkey)',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$18,612,999'),
#  ('The Sound of Music',
#   '8.1',
#   '260K',
#   'March 22, 2014 (India)',
#   '$8,200,000 (estimated)',
#   'US & Canada',
#   '$159287539',
#   'US & Canada',
#   '$413497',
#   'Sep 9 2018',
#   '$159,468,844'),
#  ('La battaglia di Algeri',
#   '8.1',
#   '65K',
#   'September 9, 1966 (Italy)',
#   '$800,000 (estimated)',
#   'US & Canada',
#   '$879794',
#   'US & Canada',
#   '$64870',
#   'Jan 11 2004',
#   '$962,002'),
#  ('The Grapes of Wrath',
#   '8.1',
#   '100K',
#   'March 15, 1940 (United States)',
#   '$800,000 (estimated)',
#   'US & Canada',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   None),
#  ('To Be or Not to Be',
#   '8.1',
#   '43K',
#   'March 6, 1942 (United States)',
#   'Not Found',
#   'US & Canada',
#   '$3270000',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$4,578,000'),
#  ('Groundhog Day',
#   '8.0',
#   '683K',
#   'February 12, 1993 (United States)',
#   '$14,600,000 (estimated)',
#   'US & Canada',
#   '$71107962',
#   'US & Canada',
#   '$12517672',
#   'Feb 14 1993',
#   '$71,108,778'),
#  ('Amores perros',
#   '8.1',
#   '252K',
#   'June 16, 2000 (Mexico)',
#   '$2,000,000 (estimated)',
#   'US & Canada',
#   '$5408467',
#   'US & Canada',
#   '$61047',
#   'Apr 1 2001',
#   '$20,908,467'),
#  ('Rebecca',
#   '8.1',
#   '146K',
#   '1940 (India)',
#   '$1,288,000 (estimated)',
#   'US & Canada',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$112,282'),
#  ('Cool Hand Luke',
#   '8.1',
#   '188K',
#   'November 1, 1967 (United States)',
#   '$3,200,000 (estimated)',
#   'US & Canada',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$126'),
#  ('The Iron Giant',
#   '8.1',
#   '226K',
#   'August 6, 1999 (United States)',
#   '$70,000,000 (estimated)',
#   'US & Canada',
#   '$23315035',
#   'US & Canada',
#   '$5732614',
#   'Aug 8 1999',
#   '$23,336,145'),
#  ('The Help',
#   '8.1',
#   '491K',
#   'November 25, 2011 (India)',
#   '$25,000,000 (estimated)',
#   'US & Canada',
#   '$169708112',
#   'US & Canada',
#   '$26044590',
#   'Aug 14 2011',
#   '$216,639,112'),
#  ('It Happened One Night',
#   '8.1',
#   '112K',
#   'February 22, 1934 (United States)',
#   '$325,000 (estimated)',
#   'US & Canada',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$14,729'),
#  ('Aladdin',
#   '8.0',
#   '464K',
#   'December 23, 1994 (India)',
#   '$28,000,000 (estimated)',
#   'US & Canada',
#   '$217350219',
#   'US & Canada',
#   '$196664',
#   'Nov 15 1992',
#   '$504,050,219'),
#  ('Dances with Wolves',
#   '8.0',
#   '289K',
#   'November 21, 1990 (United States)',
#   '$22,000,000 (estimated)',
#   'US & Canada',
#   '$184208848',
#   'US & Canada',
#   '$598257',
#   'Nov 11 1990',
#   '$424,208,848'),
#  ('Gangs of Wasseypur',
#   '8.2',
#   '103K',
#   'June 22, 2012 (India)',
#   '₹184,000,000 (estimated)',
#   'US & Canada',
#   'Not Found',
#   'US & Canada',
#   'Not Found',
#   'Not Found',
#   '$4,384,642')]

# %%
con.commit() 
con.close()
